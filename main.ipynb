# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
data = pd.read_excel('prueba.xlsx')
data.head()
# Out:
#        Fecha                 Codigo_Vendedor  \
# 0 2023-01-03  01C07
# 1 2023-01-03  01C07
# 2 2023-01-03  01C07
# 3 2023-01-03  01C07
# 4 2023-01-03  01C07
#
#                                      Nombre_Vendedor  Codigo_FV            FV  \
# 0  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 1  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 2  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 3  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 4  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
#
#    Codigo_Proveedor                                   Nombre_Proveedor  \
# 0       20604027862  LAKASA PERU S.A.                              ...
# 1       20604027862  LAKASA PERU S.A.                              ...
# 2       20521948061  COSTA VIVA S.A.C.                             ...
# 3       20100170842  PRODUCTOS EXTRAGEL Y UNIVERSAL S.A.C.         ...
# 4       20100055237  ALICORP S.A.A.                                ...
#
#    Codigo_Cliente                                     Nombre_Cliente  \
# 0          301827  ESTELA MENDOZA, YOVANA MAGNOLIA               ...
# 1          301827  ESTELA MENDOZA, YOVANA MAGNOLIA               ...
# 2          301827  ESTELA MENDOZA, YOVANA MAGNOLIA               ...
# 3          301827  ESTELA MENDOZA, YOVANA MAGNOLIA               ...
# 4          301827  ESTELA MENDOZA, YOVANA MAGNOLIA               ...
#
#        Marca  ...   Total    Distrito Categoria_Cliente   Tipo_Cliente  \
# 0      MAGIA  ...  6.6825  LOS OLIVOS         COBERTURA  BODEGA TIPICA
# 1      MAGIA  ...  7.1508  LOS OLIVOS         COBERTURA  BODEGA TIPICA
# 2    TIMONEL  ...  6.2800  LOS OLIVOS         COBERTURA  BODEGA TIPICA
# 3  UNIVERSAL  ...  9.6600  LOS OLIVOS         COBERTURA  BODEGA TIPICA
# 4   VICTORIA  ...  4.0686  LOS OLIVOS         COBERTURA  BODEGA TIPICA
#
#         TipoDocIdentidad  DocIdentidad  NumeroTelefono  \
# 0  Libreta Electoral DNI      40868050       971815115
# 1  Libreta Electoral DNI      40868050       971815115
# 2  Libreta Electoral DNI      40868050       971815115
# 3  Libreta Electoral DNI      40868050       971815115
# 4  Libreta Electoral DNI      40868050       971815115
#
#                          VendedorZonaCodigo    LATITUD   LONGITUD
# 0  0107JUBC                                 -11.995142 -77.070522
# 1  0107JUBC                                 -11.995142 -77.070522
# 2  0107JUBC                                 -11.995142 -77.070522
# 3  0107JUBC                                 -11.995142 -77.070522
# 4  0107JUBC                                 -11.995142 -77.070522
#
# [5 rows x 26 columns]

# %%
data['Fecha'] = pd.to_datetime(data['Fecha'])
data['Dia_Semana'] = data['Fecha'].dt.day_name()

data['Rechazo'] = data['Total'] < 0

#Mostrar las siguientes columnas
data[['Fecha', 'Dia_Semana', 'Codigo_Cliente', 'Nombre_Cliente', 'Total', 'Rechazo']].head()
# Out:
#        Fecha Dia_Semana  Codigo_Cliente  \
# 0 2023-01-03    Tuesday          301827
# 1 2023-01-03    Tuesday          301827
# 2 2023-01-03    Tuesday          301827
# 3 2023-01-03    Tuesday          301827
# 4 2023-01-03    Tuesday          301827
#
#                                       Nombre_Cliente   Total  Rechazo
# 0  ESTELA MENDOZA, YOVANA MAGNOLIA               ...  6.6825    False
# 1  ESTELA MENDOZA, YOVANA MAGNOLIA               ...  7.1508    False
# 2  ESTELA MENDOZA, YOVANA MAGNOLIA               ...  6.2800    False
# 3  ESTELA MENDOZA, YOVANA MAGNOLIA               ...  9.6600    False
# 4  ESTELA MENDOZA, YOVANA MAGNOLIA               ...  4.0686    False

# %%
data['Total_Compra'] = data.groupby(['Codigo_Cliente', 'Fecha'])['Total'].transform('sum')

# %%
columnas_a_eliminar = ['Codigo_FV', 'FV', 'Codigo_Proveedor', 'Nombre_Proveedor', 'Marca', 'Linea', 'Codigo_Producto', 'Nombre_Producto',
                       'Cantidad', 'Factor', 'ValorVenta', 'Total', 'Categoria_Cliente', 'Tipo_Cliente', 'TipoDocIdentidad', 'DocIdentidad',
                       'NumeroTelefono', 'VendedorZonaCodigo']

data = data.drop(columns=columnas_a_eliminar)

# %%
data = data.drop_duplicates(subset=['Codigo_Cliente', 'Fecha'])

# %% [markdown]
# # Construcción del modelo

# %%
data_enconded = pd.get_dummies(data[['Dia_Semana']], drop_first=True)

data_enconded['Rechazo'] = data['Rechazo']

X = data_enconded.drop('Rechazo', axis=1)
y = data_enconded['Rechazo']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)


print("Classification Report:")
print(classification_report(y_test, y_pred))

print("confusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      5706
#         True       0.00      0.00      0.00         9
#
#     accuracy                           1.00      5715
#    macro avg       0.50      0.50      0.50      5715
# weighted avg       1.00      1.00      1.00      5715
#
# confusion Matrix
# [[5706    0]
#  [   9    0]]
# C:\Users\WINDOWS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\WINDOWS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\WINDOWS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Crear un dataframe con los clientes únicos y sus días sin rechazos
data_no_rechazos = data[data['Rechazo'] == False]

# Agrupar por cliente y día de la semana para encontrar los días sin rechazos
clientes_dias_no_rechazo = data_no_rechazos.groupby(['Codigo_Cliente', 'Nombre_Cliente'])['Dia_Semana'].apply(lambda x: list(x.unique())).reset_index()

# Renombrar las columnas
clientes_dias_no_rechazo.columns = ['Codigo_Cliente', 'Nombre_Cliente', 'Dias_Sin_Rechazo']

# Mostrar el dataframe resultante
clientes_dias_no_rechazo.head()
# Out:
#    Codigo_Cliente                                     Nombre_Cliente  \
# 0             219  RAMOS ROJAS, JUANY CONZUELO                   ...
# 1             220  CHAVEZ PECHE BAUTISTA EUSEVIO                 ...
# 2             222  BENDEZU CHAVEZ JUSTINA WILFRIDA/FARMACIA SAN F...
# 3             223  URIOL VALVERDE PABLO HIPOLITO                 ...
# 4             386  CAMPOS CASTAÑEDA SONIA LUISA                  ...
#
#      Dias_Sin_Rechazo
# 0  [Monday, Thursday]
# 1  [Thursday, Monday]
# 2  [Thursday, Monday]
# 3  [Thursday, Monday]
# 4  [Thursday, Monday]

# %%
clientes_dias_no_rechazo.to_excel('clientes_dias_sin_rechazo.xlsx', index=False)

# %%
import pandas as pd

# Supongamos que 'data' es el dataframe original que cargamos al principio
# Y 'clientes_dias_no_rechazo' es el dataframe procesado

# Unir el dataframe original con el dataframe de días sin rechazo
data_completo = data.merge(clientes_dias_no_rechazo, on=['Codigo_Cliente', 'Nombre_Cliente'], how='left')

# Guardar el dataframe completo a un archivo Excel
output_path_completo = 'clientes_dias_sin_rechazo_completo.xlsx'
data_completo.to_excel(output_path_completo, index=False)

print(f"Archivo exportado a {output_path_completo}")
# Out:
# Archivo exportado a clientes_dias_sin_rechazo_completo.xlsx
