# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
data = pd.read_excel('prueba.xlsx')
data.head()
# Out:
#        Fecha                 Codigo_Vendedor  \
# 0 2021-01-04  01C07
# 1 2021-01-04  01C07
# 2 2021-01-04  01C07
# 3 2021-01-04  01C07
# 4 2021-01-04  01C07
#
#                                      Nombre_Vendedor  Codigo_FV            FV  \
# 0  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 1  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 2  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 3  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 4  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
#
#    Codigo_Proveedor                                   Nombre_Proveedor  \
# 0       20264846855  CLOROX PERU S.A.                              ...
# 1       20524152763  SUPERFORTE PERU S.A.C                         ...
# 2       20524152763  SUPERFORTE PERU S.A.C                         ...
# 3       20524152763  SUPERFORTE PERU S.A.C                         ...
# 4       20204441007  JOHNSON Y JOHNSON DEL PERU S.A.               ...
#
#    Codigo_Cliente                                     Nombre_Cliente  \
# 0          119719  HUERTA ROQUE, NOELIA ADILA                    ...
# 1          119719  HUERTA ROQUE, NOELIA ADILA                    ...
# 2          119719  HUERTA ROQUE, NOELIA ADILA                    ...
# 3          119719  HUERTA ROQUE, NOELIA ADILA                    ...
# 4          119719  HUERTA ROQUE, NOELIA ADILA                    ...
#
#                Marca  ...    Total       Distrito Categoria_Cliente  \
# 0             CLOROX  ...  17.2710  PUENTE PIEDRA         COBERTURA
# 1              FORTE  ...   4.0400  PUENTE PIEDRA         COBERTURA
# 2              FORTE  ...   4.0400  PUENTE PIEDRA         COBERTURA
# 3              FORTE  ...   4.0400  PUENTE PIEDRA         COBERTURA
# 4  JOHNSON & JOHNSON  ...  13.2824  PUENTE PIEDRA         COBERTURA
#
#     Tipo_Cliente       TipoDocIdentidad  DocIdentidad  NumeroTelefono  \
# 0  BODEGA BASICA  Libreta Electoral DNI      10396625  928419117 (OK)
# 1  BODEGA BASICA  Libreta Electoral DNI      10396625  928419117 (OK)
# 2  BODEGA BASICA  Libreta Electoral DNI      10396625  928419117 (OK)
# 3  BODEGA BASICA  Libreta Electoral DNI      10396625  928419117 (OK)
# 4  BODEGA BASICA  Libreta Electoral DNI      10396625  928419117 (OK)
#
#                          VendedorZonaCodigo    LATITUD  LONGITUD
# 0  0107MIB                                  -11.876642 -77.07192
# 1  0107MIB                                  -11.876642 -77.07192
# 2  0107MIB                                  -11.876642 -77.07192
# 3  0107MIB                                  -11.876642 -77.07192
# 4  0107MIB                                  -11.876642 -77.07192
#
# [5 rows x 26 columns]

# %%
data['Fecha'] = pd.to_datetime(data['Fecha'])
data['Dia_Semana'] = data['Fecha'].dt.day_name()

data['Rechazo'] = data['Total'] < 0

#Mostrar las siguientes columnas
data[['Fecha', 'Dia_Semana', 'Codigo_Cliente', 'Nombre_Cliente', 'Total', 'Rechazo']].head()
# Out:
#        Fecha Dia_Semana  Codigo_Cliente  \
# 0 2021-01-04     Monday          119719
# 1 2021-01-04     Monday          119719
# 2 2021-01-04     Monday          119719
# 3 2021-01-04     Monday          119719
# 4 2021-01-04     Monday          119719
#
#                                       Nombre_Cliente    Total  Rechazo
# 0  HUERTA ROQUE, NOELIA ADILA                    ...  17.2710    False
# 1  HUERTA ROQUE, NOELIA ADILA                    ...   4.0400    False
# 2  HUERTA ROQUE, NOELIA ADILA                    ...   4.0400    False
# 3  HUERTA ROQUE, NOELIA ADILA                    ...   4.0400    False
# 4  HUERTA ROQUE, NOELIA ADILA                    ...  13.2824    False

# %%
data['Total_Compra'] = data.groupby(['Codigo_Cliente', 'Fecha'])['Total'].transform('sum')
# Out:
#        Fecha                 Codigo_Vendedor  \
# 0 2021-01-04  01C07
# 1 2021-01-04  01C07
# 2 2021-01-04  01C07
# 3 2021-01-04  01C07
# 4 2021-01-04  01C07
#
#                                      Nombre_Vendedor  Codigo_FV            FV  \
# 0  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 1  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 2  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 3  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
# 4  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...        107  RUTA Mixta C
#
#    Codigo_Proveedor                                   Nombre_Proveedor  \
# 0       20264846855  CLOROX PERU S.A.                              ...
# 1       20524152763  SUPERFORTE PERU S.A.C                         ...
# 2       20524152763  SUPERFORTE PERU S.A.C                         ...
# 3       20524152763  SUPERFORTE PERU S.A.C                         ...
# 4       20204441007  JOHNSON Y JOHNSON DEL PERU S.A.               ...
#
#    Codigo_Cliente                                     Nombre_Cliente  \
# 0          119719  HUERTA ROQUE, NOELIA ADILA                    ...
# 1          119719  HUERTA ROQUE, NOELIA ADILA                    ...
# 2          119719  HUERTA ROQUE, NOELIA ADILA                    ...
# 3          119719  HUERTA ROQUE, NOELIA ADILA                    ...
# 4          119719  HUERTA ROQUE, NOELIA ADILA                    ...
#
#                Marca  ...   Tipo_Cliente       TipoDocIdentidad DocIdentidad  \
# 0             CLOROX  ...  BODEGA BASICA  Libreta Electoral DNI     10396625
# 1              FORTE  ...  BODEGA BASICA  Libreta Electoral DNI     10396625
# 2              FORTE  ...  BODEGA BASICA  Libreta Electoral DNI     10396625
# 3              FORTE  ...  BODEGA BASICA  Libreta Electoral DNI     10396625
# 4  JOHNSON & JOHNSON  ...  BODEGA BASICA  Libreta Electoral DNI     10396625
#
#    NumeroTelefono                        VendedorZonaCodigo    LATITUD  \
# 0  928419117 (OK)  0107MIB                                  -11.876642
# 1  928419117 (OK)  0107MIB                                  -11.876642
# 2  928419117 (OK)  0107MIB                                  -11.876642
# 3  928419117 (OK)  0107MIB                                  -11.876642
# 4  928419117 (OK)  0107MIB                                  -11.876642
#
#    LONGITUD Dia_Semana Rechazo Total_Compra
# 0 -77.07192     Monday   False      42.6734
# 1 -77.07192     Monday   False      42.6734
# 2 -77.07192     Monday   False      42.6734
# 3 -77.07192     Monday   False      42.6734
# 4 -77.07192     Monday   False      42.6734
#
# [5 rows x 29 columns]

# %%
columnas_a_eliminar = ['Codigo_FV', 'FV', 'Codigo_Proveedor', 'Nombre_Proveedor', 'Marca', 'Linea', 'Codigo_Producto', 'Nombre_Producto',
                       'Cantidad', 'Factor', 'ValorVenta', 'Total', 'Categoria_Cliente', 'Tipo_Cliente', 'TipoDocIdentidad', 'DocIdentidad',
                       'NumeroTelefono', 'VendedorZonaCodigo']

data = data.drop(columns=columnas_a_eliminar)
# Out:
#        Fecha                 Codigo_Vendedor  \
# 0 2021-01-04  01C07
# 1 2021-01-04  01C07
# 2 2021-01-04  01C07
# 3 2021-01-04  01C07
# 4 2021-01-04  01C07
#
#                                      Nombre_Vendedor  Codigo_Cliente  \
# 0  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...          119719
# 1  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...          119719
# 2  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...          119719
# 3  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...          119719
# 4  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...          119719
#
#                                       Nombre_Cliente       Distrito  \
# 0  HUERTA ROQUE, NOELIA ADILA                    ...  PUENTE PIEDRA
# 1  HUERTA ROQUE, NOELIA ADILA                    ...  PUENTE PIEDRA
# 2  HUERTA ROQUE, NOELIA ADILA                    ...  PUENTE PIEDRA
# 3  HUERTA ROQUE, NOELIA ADILA                    ...  PUENTE PIEDRA
# 4  HUERTA ROQUE, NOELIA ADILA                    ...  PUENTE PIEDRA
#
#      LATITUD  LONGITUD Dia_Semana  Rechazo  Total_Compra
# 0 -11.876642 -77.07192     Monday    False       42.6734
# 1 -11.876642 -77.07192     Monday    False       42.6734
# 2 -11.876642 -77.07192     Monday    False       42.6734
# 3 -11.876642 -77.07192     Monday    False       42.6734
# 4 -11.876642 -77.07192     Monday    False       42.6734

# %%
data = data.drop_duplicates(subset=['Codigo_Cliente', 'Fecha'])
# Out:
#         Fecha                 Codigo_Vendedor  \
# 0  2021-01-04  01C07
# 5  2021-01-04  01B07
# 17 2021-01-05  01C07
# 28 2021-01-05  01C07
# 31 2021-01-05  01C07
#
#                                       Nombre_Vendedor  Codigo_Cliente  \
# 0   C07 ALVAREZ OSCCO, DALMACIO PERCY             ...          119719
# 5   B07 ALCANTARA ALVARADO, GABY CAROLINA         ...          232873
# 17  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...            7120
# 28  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...          227279
# 31  C07 ALVAREZ OSCCO, DALMACIO PERCY             ...           34479
#
#                                        Nombre_Cliente              Distrito  \
# 0   HUERTA ROQUE, NOELIA ADILA                    ...         PUENTE PIEDRA
# 5   VASQUEZ  AGUIRRE, RICARDO                     ...                 ANCON
# 17  FARFAN NORIEGA CONSTANTE RAFAEL               ...  SAN MARTIN DE PORRES
# 28  MAQUI  CHAVEZ, ERICA ELIZABETH                ...                CALLAO
# 31  NOA NURY PACO                                 ...                CALLAO
#
#       LATITUD   LONGITUD Dia_Semana  Rechazo  Total_Compra
# 0  -11.876642 -77.071920     Monday    False     42.673400
# 5  -11.773983 -77.171851     Monday    False    327.428645
# 17 -11.997572 -77.104095    Tuesday    False    276.603500
# 28 -12.000133 -77.102884    Tuesday    False     48.077200
# 31 -12.000406 -77.105794    Tuesday    False     57.020000

# %% [markdown]
# # Construcción del modelo

# %%
data_enconded = pd.get_dummies(data[['Dia_Semana']], drop_first=True)

data_enconded['Rechazo'] = data['Rechazo']

X = data_enconded.drop('Rechazo', axis=1)
y = data_enconded['Rechazo']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)


print("Classification Report:")
print(classification_report(y_test, y_pred))

print("confusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       332
#         True       0.00      0.00      0.00         1
#
#     accuracy                           1.00       333
#    macro avg       0.50      0.50      0.50       333
# weighted avg       0.99      1.00      1.00       333
#
# confusion Matrix
# [[332   0]
#  [  1   0]]
# C:\Users\WINDOWS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\WINDOWS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\WINDOWS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Crear un dataframe con los clientes únicos y sus días sin rechazos
data_no_rechazos = data[data['Rechazo'] == False]

# Agrupar por cliente y día de la semana para encontrar los días sin rechazos
clientes_dias_no_rechazo = data_no_rechazos.groupby(['Codigo_Cliente', 'Nombre_Cliente'])['Dia_Semana'].apply(lambda x: list(x.unique())).reset_index()

# Renombrar las columnas
clientes_dias_no_rechazo.columns = ['Codigo_Cliente', 'Nombre_Cliente', 'Dias_Sin_Rechazo']

# Mostrar el dataframe resultante
clientes_dias_no_rechazo.head()
# Out:
#    Codigo_Cliente                                     Nombre_Cliente  \
# 0             220  CHAVEZ PECHE BAUTISTA EUSEVIO                 ...
# 1             223  URIOL VALVERDE PABLO HIPOLITO                 ...
# 2             386  CAMPOS CASTAÑEDA SONIA LUISA                  ...
# 3             464  ARANA BARRON PABLO ENRIQUE                    ...
# 4            1003  PICON CUEVA JULIO                             ...
#
#      Dias_Sin_Rechazo
# 0          [Thursday]
# 1  [Monday, Thursday]
# 2            [Monday]
# 3   [Friday, Tuesday]
# 4            [Monday]

# %%
clientes_dias_no_rechazo.to_excel('clientes_dias_sin_rechazo.xlsx', index=False)

# %%
import pandas as pd

# Supongamos que 'data' es el dataframe original que cargamos al principio
# Y 'clientes_dias_no_rechazo' es el dataframe procesado

# Unir el dataframe original con el dataframe de días sin rechazo
data_completo = data.merge(clientes_dias_no_rechazo, on=['Codigo_Cliente', 'Nombre_Cliente'], how='left')

# Guardar el dataframe completo a un archivo Excel
output_path_completo = 'clientes_dias_sin_rechazo_completo.xlsx'
data_completo.to_excel(output_path_completo, index=False)

print(f"Archivo exportado a {output_path_completo}")
# Out:
# Archivo exportado a clientes_dias_sin_rechazo_completo.xlsx
